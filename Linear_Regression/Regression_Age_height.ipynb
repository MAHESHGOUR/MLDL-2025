# %% [markdown]
# # Install the following

# %%
# !pip install numpy
# !pip install pandas
# !pip install scikit-learn

# %% [markdown]
# # Importing libraraies

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading dataset from the csv file

# %%
df = pd.read_csv("D:\SIStec\ML\Regression\datasets\synthetic_age_height_data3.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\hp\AppData\Local\Temp\ipykernel_25268\574245271.py:1: SyntaxWarning: invalid escape sequence '\S'
#   df = pd.read_csv("D:\SIStec\ML\Regression\datasets\synthetic_age_height_data3.csv")

# %%
df.head(10)
# Out:
#    Age  Height(ft)
# 0   56        5.91
# 1   97        5.29
# 2   19        6.06
# 3   76        5.67
# 4   65        5.66
# 5   25        6.12
# 6   87        5.90
# 7   91        5.86
# 8   79        5.56
# 9   79        5.67

# %% [markdown]
# ### Visualize the data using scatter plot, to see the relationship between the age and Height

# %%
plt.scatter(df['Age'],df['Height(ft)'])
plt.xlabel('Age')
plt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %% [markdown]
# ## split the dataset into training and test sets.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# ## Import Linear regression model from the SKlearn Library

# %%
from sklearn.linear_model import  LinearRegression

# %% [markdown]
# ## Define the model

# %%
model=LinearRegression()

# %% [markdown]
# ## Train the model

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## See the Values of co-efficient/slope.

# %%
model.coef_
# Out:
# array([0.00634637])

# %% [markdown]
# ## See the Values of intercept.

# %%
model.intercept_
# Out:
# np.float64(5.306210187000563)

# %% [markdown]
# ## predict the values for test set

# %%
X_test
# Out:
#     Age
# 83   66
# 30   63
# 56   57
# 24   80
# 16   92
# 23   37
# 2    19
# 27   93
# 28   53
# 13   26
# 99   93
# 92   44
# 76   97
# 14   57
# 0    56
# 21   64
# 3    76
# 29   95
# 61   75
# 79   94

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([5.72507035, 5.70603126, 5.66795306, 5.81391948, 5.89007588,
#        5.54102574, 5.42679114, 5.89642224, 5.64256759, 5.47121571,
#        5.89642224, 5.5854503 , 5.92180771, 5.66795306, 5.66160669,
#        5.71237762, 5.78853402, 5.90911497, 5.78218765, 5.90276861])

# %%
# single input value
x_single = np.array([[11.0]])  # shape must be (1, 1)

# predict
prediction = model.predict(x_single)
print("Predicted value:", prediction[0])
# Out:
# Predicted value: 5.376020214938487
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # visulize the best fit line

# %%
plt.scatter(df['Age'],df['Height(ft)'])
plt.plot(X_train,model.predict(X_train),color='red')
plt.xlabel('Age')
plt.ylabel('Height(in ft)')
# Out:
# Text(0, 0.5, 'Height(in ft)')

# %%
model.coef_
# Out:
# array([0.00634637])

# %%
model.intercept_
# Out:
# 5.306210187000563

# %%
X_test
# Out:
#     Age
# 83   66
# 30   63
# 56   57
# 24   80
# 16   92
# 23   37
# 2    19
# 27   93
# 28   53
# 13   26
# 99   93
# 92   44
# 76   97
# 14   57
# 0    56
# 21   64
# 3    76
# 29   95
# 61   75
# 79   94

# %%
y_test
# Out:
# 83    5.81
# 30    5.83
# 56    5.81
# 24    5.72
# 16    5.83
# 23    6.25
# 2     6.06
# 27    5.82
# 28    5.88
# 13    5.96
# 99    5.40
# 92    5.95
# 76    5.76
# 14    5.62
# 0     5.91
# 21    5.68
# 3     5.67
# 29    5.59
# 61    5.74
# 79    5.54
# Name: Height(ft), dtype: float64

# %%
y_pred
# Out:
# array([5.72507035, 5.70603126, 5.66795306, 5.81391948, 5.89007588,
#        5.54102574, 5.42679114, 5.89642224, 5.64256759, 5.47121571,
#        5.89642224, 5.5854503 , 5.92180771, 5.66795306, 5.66160669,
#        5.71237762, 5.78853402, 5.90911497, 5.78218765, 5.90276861])

# %% [markdown]
# # Evaluation Metrics

# %% [markdown]
# # 📊 Linear Regression Evaluation Metrics
#
# ---
#
# ## 1. Mean Absolute Error (MAE)
#
# **Formula:**
# $ \text{MAE} = \frac{1}{n} \sum_{i=1}^{n} \left| y_i - \hat{y}_i \right| $
#
# **Description:**
# - Measures the average magnitude of the errors in predictions.
# - Does **not** penalize large errors heavily.
#
# **Interpretation:**
# - Lower is better.
# - Same unit as the target variable.
#
# ---
#
# ## 2. Mean Squared Error (MSE)
#
# **Formula:**
# $ \text{MSE} = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2 $
#
# **Description:**
# - Penalizes larger errors more than MAE due to squaring.
# - Sensitive to outliers.
#
# **Interpretation:**
# - Lower is better.
# - Units are squared (e.g., ft²).
#
# ---
#
# ## 3. Root Mean Squared Error (RMSE)
#
# **Formula:**
# $ \text{RMSE} = \sqrt{\text{MSE}} $
#
# **Description:**
# - Square root of MSE.
# - More interpretable than MSE (in original units).
#
# **Interpretation:**
# - Lower is better.
# - Same unit as the target variable.
#
# ---
#
# # 📊 R² (R-squared) – Coefficient of Determination
#
# ## 🔷 What is R²?
#
# **R² (R-squared)** is a statistical metric that indicates how well the independent variables explain the variability of the dependent variable in a regression model.
#
# ---
#
# ## 📐 Formula
#
# $$
# R^2 = 1 - \frac{SS_{\text{res}}}{SS_{\text{tot}}}
# $$
#
# Where:
#
# - \( SS_{\text{res}} = \sum_{i=1}^{n}(y_i - \hat{y}_i)^2 \) → Residual Sum of Squares
# - \( SS_{\text{tot}} = \sum_{i=1}^{n}(y_i - \bar{y})^2 \) → Total Sum of Squares
# - \( y_i \): Actual value
# - \( \hat{y}_i \): Predicted value
# - \( \bar{y} \): Mean of actual values
#
# ---
#
# ## ✅ Interpretation
#
# | R² Value | Meaning |
# |----------|---------|
# | 1.0      | Perfect fit |
# | 0.9+     | Excellent |
# | 0.7–0.9  | Good |
# | 0.5–0.7  | Moderate |
# | < 0.5    | Poor |
# | < 0      | Worse than mean predictor |
#
# ---
#
# ## 🧠 Intuition
#
# - **R² = 1** → Model explains all variance.
# - **R² = 0** → Model explains nothing (equal to mean prediction).
# - **R² < 0** → Model is worse than simply predicting the mean.
#
# ---
#
# ## 📊 Use Cases
#
# - Regression model evaluation
# - Model comparison
# - Diagnosing underfitting and overfitting
#
# ---
#
# ## ⚠️ Limitations
#
# 1. Doesn’t imply causation
# 2. Sensitive to outliers
# 3. Can’t compare across different datasets
# 4. Not suitable for nonlinear models
# 5. Doesn’t penalize overfitting (high R² might be misleading)
#
# ---
#
# ## ➕ Adjusted R²
#
# To penalize for adding too many features, use **Adjusted R²**:
#
# $$ \[
# \text{Adjusted } R^2 = 1 - \left( \frac{(1 - R^2)(n - 1)}{n - k - 1} \right)
# \] $$
#
# Where:
# - \( n \) = number of samples
# - \( k \) = number of predictors
#
# ---
#
# ## 🛠️ Python Example
#
# ```python
# from sklearn.metrics import r2_score
#
# y_true = [3, -0.5, 2, 7]
# y_pred = [2.5, 0.0, 2, 8]
#
# r2 = r2_score(y_true, y_pred)
# print("R-squared:", r2)
#
# ---
#
# ## ✅ Summary Table
#
# | Metric         | Penalizes Large Errors | Units          | Ideal Value |
# |----------------|------------------------|----------------|--------------|
# | **MAE**        | No                     | Same as target | 0            |
# | **MSE**        | Yes                    | Squared units  | 0            |
# | **RMSE**       | Yes                    | Same as target | 0            |
# | **R² Score**   | No                     | Dimensionless  | 1            |
# | **Adjusted R²**| No                     | Dimensionless  | Close to 1   |
#
# ---

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
## 🧪 Example Code (Scikit-learn)


from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# y_true = actual values, y_pred = predicted values
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# MAE: 0.24
# MSE: 0.10
# RMSE: 0.31
# R² Score: -1.89
